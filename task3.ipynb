# %% [markdown]
# ## Importing necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# ## Reading CSV file

# %%
df=pd.read_csv(r'C:\Users\welcome\Desktop\bank.csv')

# %% [markdown]
# ## Overview of the DataFrame

# %%
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# ## Checking top 5 rows data

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %% [markdown]
# ## checking data from bottom

# %%
df.tail()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %% [markdown]
# ## some information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Exploring the Shape of a DataFrame

# %%
df.shape
# Out:
# (11162, 17)

# %% [markdown]
# ## checking the columns of dataset

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# ## Understanding Data Types in a DataFrame

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %% [markdown]
# ## Count of Data Types in the DataFrame

# %%
df.dtypes.value_counts()
# Out:
# object    10
# int64      7
# Name: count, dtype: int64

# %% [markdown]
# ## checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## checking for missing values

# %%
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %% [markdown]
# ## Identifying Categorical and Numerical Columns in the DataFrame

# %%
cat_cols=df.select_dtypes(include='object').columns
print(cat_cols)
num_cols=df.select_dtypes(exclude='object').columns
print(num_cols)
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'deposit'],
#       dtype='object')
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %% [markdown]
# ## Quick Overview of Data with

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
df.describe(include='object')
# Out:
#                job  marital  education default housing   loan   contact  \
# count        11162    11162      11162   11162   11162  11162     11162
# unique          12        3          4       2       2      2         3
# top     management  married  secondary      no      no     no  cellular
# freq          2566     6351       5476   10994    5881   9702      8042
#
#         month poutcome deposit
# count   11162    11162   11162
# unique     12        4       2
# top       may  unknown      no
# freq     2824     8326    5873

# %% [markdown]
# ## Visualizing the Distributions of Numerical Variables

# %%
df.hist(figsize=(10,10),color='YELLOW')
plt.show()

# %% [markdown]
# ## Preparing Subplots for Categorical Column Visualizations

# %%
num_plots=len(cat_cols)
num_rows=(num_plots+1)
num_cols=2

# %%
plt.figure(figsize=(20,25))

# %% [markdown]
# ## Visualizing Categorical Columns with Count Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import math


n_features = len(cat_cols)


num_cols = 3  
num_rows = math.ceil(n_features / num_cols)


plt.figure(figsize=(num_cols * 6, num_rows * 5))  

for i, feature in enumerate(cat_cols, 1):
    plt.subplot(num_rows, num_cols, i)
    
    sns.countplot(data=df, x=feature, hue=feature, palette='Wistia', legend=False)
    
    plt.title(f'Bar plot of {feature}', fontsize=10)  
    plt.xlabel(feature, fontsize=8)
    plt.ylabel('Count', fontsize=8) 
    plt.xticks(rotation=45, fontsize=8)

# %% [markdown]
# ## Generating Box Plots for All Columns

# %%
df.plot(kind='box',subplots=True, layout=(2,5),figsize=(20,10),color='red')
plt.show()

# %% [markdown]
# ## Removing Outliers Using IQR for `age`, `campaign`, and `duration`

# %%
column=df[['age','campaign','duration']]
q1=np.percentile(column,25)
q3=np.percentile(column,75)
iqr=q3-q1
lower_bound=q1-1.5*iqr
upper_bound=q3+1.5*iqr
df[['age','campaign','duration']]=column[(column>lower_bound)&(column<upper_bound)]

# %% [markdown]
# ## Visualizing Data Distribution with Box Plots for All Columns

# %%
df.plot(kind='box',subplots=True,layout=(2,5),figsize=(20,10),color='red')
plt.show()

# %% [markdown]
# ## Visualizing High Correlations Between Numerical Features with a Heatmap

# %%
numeric_df=df.drop(columns=cat_cols)
corr=numeric_df.corr()
print(corr)
corr=corr[abs(corr)>=0.90]
sns.heatmap(corr,annot=True,cmap='Set3',linewidths=0.2)
plt.show()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.112300 -0.000762 -0.007572 -0.005278  0.002774  0.020169
# balance   0.112300  1.000000  0.010467  0.041714 -0.013894  0.017411  0.030805
# day      -0.000762  0.010467  1.000000 -0.086588  0.137007 -0.077232 -0.058981
# duration -0.007572  0.041714 -0.086588  1.000000 -0.201434  0.088653  0.066075
# campaign -0.005278 -0.013894  0.137007 -0.201434  1.000000 -0.102726 -0.049699
# pdays     0.002774  0.017411 -0.077232  0.088653 -0.102726  1.000000  0.507272
# previous  0.020169  0.030805 -0.058981  0.066075 -0.049699  0.507272  1.000000

# %% [markdown]
# ## Defining Highly Correlated Columns

# %%
high_corr_cols = ['emp.var.rate', 'euribor3m', 'nr.employed']

# %% [markdown]
# ## Creating a Copy of `df` and Listing Its Columns

# %%
df1=df.copy()
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
existing_cols_to_drop = [col for col in high_corr_cols if col in df1.columns]
df1.drop(columns=existing_cols_to_drop, inplace=True)

# %%
df1.shape
# Out:
# (11162, 17)

# %% [markdown]
# ## Label Encoding of Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df_encoded = df1.apply(lb.fit_transform)
df_encoded
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       41    0        1          1        0     2288        1     0        2
# 1       38    0        1          1        0      469        0     0        2
# 2       23    9        1          1        0     1618        1     0        2
# 3       37    7        1          1        0     2356        1     0        2
# 4       36    0        1          2        0      608        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 11157   15    1        2          0        0      425        1     0        0
# 11158   21    7        1          1        0     1149        0     0        2
# 11159   14    9        2          1        0      453        0     0        0
# 11160   25    9        1          1        0      424        0     1        0
# 11161   16    9        1          1        0      424        0     0        0
#
# ...

# %% [markdown]
# ## Checking the Value Counts of the `deposit` Column in the Encoded DataFrame

# %%
df_encoded['deposit'].value_counts()
# Out:
# deposit
# 0    5873
# 1    5289
# Name: count, dtype: int64

# %% [markdown]
# ## Splitting the Encoded DataFrame into Features (`x`) and Target (`y`)

# %%
x=df_encoded.drop('deposit',axis=1)
y=df_encoded['deposit']
print(x.shape)
print(y.shape)
print(type(x))
print(type(y))
# Out:
# (11162, 16)
# (11162,)
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Splitting Data into Training and Test Sets for Model Training

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test,=train_test_split(x,y,test_size=0.25,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(x_test.shape)
# Out:
# (8371, 16)
# (2791, 16)
# (8371,)
# (2791, 16)

# %% [markdown]
# ## Defining Model Evaluation Functions: Accuracy, Confusion Matrix, and Scores

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
def eval_model(y_test,y_pred):
    acc=accuracy_score(y_test,y_pred)
    print('Accuracy_Score',acc)
    cm=confusion_matrix(y_test,y_pred)
    print('Confusion Matrix\n',cm)
    print('Classification Report\n',classification_report(y_test,y_pred))

def mscore(model):
    train_score=model.score(x_train,y_train)
    test_score=model.score(x_test,y_test)
    print('Training Score',train_score)
    print('Testing Score',test_score)

# %% [markdown]
# ## Training a Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=10)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=10)

# %% [markdown]
# ## Evaluating the Performance of the Trained Decision Tree Classifier

# %%
mscore(dt)
# Out:
# Training Score 0.8058774339983276
# Testing Score 0.7835901110713006

# %% [markdown]
# ## Making Predictions with the Trained Decision Tree Classifier

# %%
ypred_dt=dt.predict(x_test)
print(ypred_dt)
# Out:
# [0 0 1 ... 0 1 0]

# %% [markdown]
# ## Evaluating the Predictions of the Decision Tree Classifier

# %%
eval_model(y_test,ypred_dt)
# Out:
# Accuracy_Score 0.7835901110713006
# Confusion Matrix
#  [[1047  410]
#  [ 194 1140]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.84      0.72      0.78      1457
#            1       0.74      0.85      0.79      1334
#
#     accuracy                           0.78      2791
#    macro avg       0.79      0.79      0.78      2791
# weighted avg       0.79      0.78      0.78      2791

# %% [markdown]
# ## Preparing for Decision Tree Visualization: Feature Names and Class Labels

# %%
from sklearn.tree import plot_tree
cn=['no','yes']
fn=x_train.columns
print(fn)
print(cn)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome'],
#       dtype='object')
# ['no', 'yes']

# %% [markdown]
# ## Visualizing the Trained Decision Tree Classifier

# %%
plt.figure(figsize=(30,10))
plot_tree(dt,class_names=cn,filled=True)
plt.show()

# %% [markdown]
# ## Training a Decision Tree Classifier with Entropy Criterion

# %%
dt1=DecisionTreeClassifier(criterion='entropy',max_depth=4,min_samples_split=15)
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_split=15)

# %%
mscore(dt1)
# Out:
# Training Score 0.7675307609604587
# Testing Score 0.7642422070942314

# %%
ypred_dt1=dt.predict(x_test)
print(ypred_dt1)
# Out:
# [0 0 1 ... 0 1 0]

# %%
eval_model(y_test,ypred_dt1)
# Out:
# Accuracy_Score 0.7835901110713006
# Confusion Matrix
#  [[1047  410]
#  [ 194 1140]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.84      0.72      0.78      1457
#            1       0.74      0.85      0.79      1334
#
#     accuracy                           0.78      2791
#    macro avg       0.79      0.79      0.78      2791
# weighted avg       0.79      0.78      0.78      2791

# %% [markdown]
# ## Visualizing the Second Trained Decision Tree Classifier (Entropy Criterion)

# %%
plt.figure(figsize=(30,10))
plot_tree(dt1,class_names=cn,filled=True)
plt.show()
